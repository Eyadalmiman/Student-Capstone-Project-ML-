# %% [markdown]
# **Imports**

# %%
import pandas as pd

# %% [markdown]
# **Code**

# %% [markdown]
# first we make a variable called "df" to put our dataset in

# %%
df = pd.read_csv("Data/IMDB Dataset.csv")

# %% [markdown]
# Then we print the first 5 rows of data

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# Here we print the shape of the dataset (how many rows and columns it has)

# %%
print(f"The shape of the dataset is : {df.shape}")
# Out:
# The shape of the dataset is : (50000, 2)

# %% [markdown]
# Here we check for missing values in the dataset, which whe didn't find any missing values across the whole dataset

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64
